# %%
from evaluation import calculate_EER

# %%
# Baseline
BASELINE_ASV_SCORE_FILE = "/home/jsudan/wav2vec_contr_loss/scores/baseline/facebook/wav2vec2-xls-r-300m/score_cm_eval.txt"
BASELINE_ITW_SCORE_FILE = "/home/jsudan/wav2vec_contr_loss/scores/baseline/facebook/wav2vec2-xls-r-300m/score_cm_itw.txt"
baseline_eer_asv = calculate_EER(BASELINE_ASV_SCORE_FILE)
baseline_eer_itw = calculate_EER(BASELINE_ITW_SCORE_FILE)

# Vanilla SupCon
vanilla_supcon_ASV_SCORE_FILE = "/home/jsudan/wav2vec_contr_loss/scores/supcon_temp_0.1/facebook/wav2vec2-xls-r-300m/score_cm_eval.txt"
vanilla_supcon_ITW_SCORE_FILE = "/home/jsudan/wav2vec_contr_loss/scores/supcon_temp_0.1/facebook/wav2vec2-xls-r-300m/score_cm_itw.txt"
vanilla_supcon_eer_asv = calculate_EER(vanilla_supcon_ASV_SCORE_FILE)
vanilla_supcon_eer_itw = calculate_EER(vanilla_supcon_ITW_SCORE_FILE)

# SupCon with Uniformity
supcon_uniformity_ASV_SCORE_FILE = "/home/jsudan/wav2vec_contr_loss/scores/supcon_uniformity_weight_0.1/facebook/wav2vec2-xls-r-300m/score_cm_eval.txt"
supcon_uniformity_ITW_SCORE_FILE = "/home/jsudan/wav2vec_contr_loss/scores/supcon_uniformity_weight_0.1/facebook/wav2vec2-xls-r-300m/score_cm_itw.txt"
supcon_uniformity_eer_asv = calculate_EER(supcon_uniformity_ASV_SCORE_FILE)
supcon_uniformity_eer_itw = calculate_EER(supcon_uniformity_ITW_SCORE_FILE)

# Supcon w/t Geodesic distance
supcon_geodesic_dist_ASV_SCORE_FILE = "/home/jsudan/wav2vec_contr_loss/scores/supcon_geodesic_temp_0.1/facebook/wav2vec2-xls-r-300m/score_cm_eval.txt"
supcon_geodesic_dist_ITW_SCORE_FILE = "/home/jsudan/wav2vec_contr_loss/scores/supcon_geodesic_temp_0.1/facebook/wav2vec2-xls-r-300m/score_cm_itw.txt"
supcon_geodesic_dist_eer_asv = calculate_EER(supcon_geodesic_dist_ASV_SCORE_FILE)
supcon_geodesic_dist_eer_itw = calculate_EER(supcon_geodesic_dist_ITW_SCORE_FILE)

# %%
# Baseline
print("Baseline Performance:")
print(f"ASVSpoof 19 LA: {baseline_eer_asv}")
print(f"In The Wild: {baseline_eer_itw}")
print("\n")

# Vanilla SupCon
print("Vanilla SupCon Performance:")
print(f"ASVSpoof 19 LA: {vanilla_supcon_eer_asv}")
print(f"In The Wild: {vanilla_supcon_eer_itw}")
print("\n")

# SupCon with Uniformity
print("SupCon with Uniformity Performance:")
print(f"ASVSpoof 19 LA: {supcon_uniformity_eer_asv}")
print(f"In The Wild: {supcon_uniformity_eer_itw}")
print("\n")

# Supcon w/t Geodesic distance
print("Supcon w/t Geodesic distance Performance:")
print(f"ASVSpoof 19 LA: {supcon_geodesic_dist_eer_asv}")
print(f"In The Wild: {supcon_geodesic_dist_eer_itw}")
print("\n")
# Out:
# Baseline Performance:
# ASVSpoof 19 LA: 0.28521016964252854
# In The Wild: 15.935248871549806
#
#
# Vanilla SupCon Performance:
# ASVSpoof 19 LA: 0.29905250398896793
# In The Wild: 15.884813233188238
#
#
# SupCon with Uniformity Performance:
# ASVSpoof 19 LA: 0.231406218437542
# In The Wild: 18.509021861398224
#
#
# Supcon w/t Geodesic distance Performance:
# ASVSpoof 19 LA: 0.3698295619019355
# In The Wild: 10.299323509833748
