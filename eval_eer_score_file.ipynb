# %%
from evaluation import calculate_EER

# %%
# wav2vec2-xls-r-300m
ASV_SCORE_FILE = "/home/jsudan/wav2vec_contr_loss/scores/facebook/wav2vec2-xls-r-300m/score_cm_eval.txt"
ITW_SCORE_FILE = "/home/jsudan/wav2vec_contr_loss/scores/facebook/wav2vec2-xls-r-300m/score_cm_itw.txt"

# wav2vec2-large-960h
# ASV_SCORE_FILE = "/home/jsudan/wav2vec_contr_loss/scores/facebook/wav2vec2-large-960h/score_cm_eval.txt"
# ITW_SCORE_FILE = "/home/jsudan/wav2vec_contr_loss/scores/facebook/wav2vec2-large-960h/score_cm_itw.txt"

eer_asv = calculate_EER(ASV_SCORE_FILE)
eer_itw = calculate_EER(ITW_SCORE_FILE)

# %%
print(f"ASVSpoof 19 LA: {eer_asv}")
print(f"In The Wild: {eer_itw}")
# Out:
# ASVSpoof 19 LA: 0.13607526419323732
# In The Wild: 15.994925327495677
